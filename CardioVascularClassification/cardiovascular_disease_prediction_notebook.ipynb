# %% [markdown]
# # TASK #1 : UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# Aim of the problem is to detect the presence or absence of cardiovascular disease in person based on the given features.
# Features available are:
#
#
# - Age | Objective Feature | age | int (days)
# - Height | Objective Feature | height | int (cm) |
# - Weight | Objective Feature | weight | float (kg) |
# - Gender | Objective Feature | gender | categorical code |
# - Systolic blood pressure | Examination Feature | ap_hi | int |
# - Diastolic blood pressure | Examination Feature | ap_lo | int |
# - Cholesterol | Examination Feature | cholesterol | 1: normal, 2: above normal, 3: well above normal |
# - Glucose | Examination Feature | gluc | 1: normal, 2: above normal, 3: well above normal |
# - Smoking | Subjective Feature | smoke | binary |
# - Alcohol intake | Subjective Feature | alco | binary |
# - Physical activity | Subjective Feature | active | binary |
# - Presence or absence of cardiovascular disease | Target Variable | cardio | binary |
#
# Note that:
# - Objective: factual information;
# - Examination: results of medical examination;
# - Subjective: information given by the patient.
#
# Data Source:https://www.kaggle.com/sulianova/cardiovascular-disease-dataset

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file 
cardio_df = pd.read_csv("cardio_train.csv", sep=";")

# %%
cardio_df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# # TASK #3: PERFORM EXPLORATORY DATA ANALYSIS

# %%
# Drop id

cardio_df = cardio_df.drop(columns = 'id')

# %%
# since the age is given in days, we convert it into years

cardio_df['age'] = cardio_df['age']/365

# %%
cardio_df.tail()
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  52.712329       2     168    76.0    120     80            1     1
# 69996  61.920548       1     158   126.0    140     90            2     2
# 69997  52.235616       2     183   105.0    180     90            3     1
# 69998  61.454795       1     163    72.0    135     80            1     2
# 69999  56.273973       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %%
# checking the null values
cardio_df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
# Checking the dataframe information

cardio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  float64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 6.4 MB

# %%
# Statistical summary of the dataframe
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.339358      1.349571    164.359229     74.205690    128.817286
# std        6.759594      0.476838      8.210126     14.395757    154.011419
# min       29.583562      1.000000     55.000000     10.000000   -150.000000
# 25%       48.394521      1.000000    159.000000     65.000000    120.000000
# 50%       53.980822      1.000000    165.000000     72.000000    120.000000
# 75%       58.430137      2.000000    170.000000     82.000000    140.000000
# max       64.967123      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# std      188.472530      0.680250      0.572270      0.283484      0.225568
# min      -70.000000      1.000000      1.000000      0.000000      0.000000
# 25%       80.000000      1.000000      1.000000      0.000000      0.000000
# 50%       80.000000      1.000000      1.000000      0.000000      0.000000
# 75%       90.000000      2.000000      1.000000      0.000000      0.000000
# max    11000.000000      3.000000      3.000000      1.000000      1.000000
#
#              active        cardio
# count  70000.000000  70000.000000
# mean       0.803729      0.499700
# std        0.397179      0.500003
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000

# %% [markdown]
# MINI CHALLENGE
# - Obtain the features of the individuals who are older than 64.8 years old

# %%
cardio_df[cardio_df['age']>64.8]
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 395    64.824658       2     160    78.0    140     90            1     1
# 643    64.802740       1     154    79.0    130     80            1     1
# 2936   64.808219       2     156    60.0    140     90            1     1
# 4295   64.849315       1     169    75.0    120     80            1     1
# 9787   64.838356       2     165    70.0    120     80            1     1
# 10422  64.816438       2     177   102.0    130     80            1     2
# 16439  64.821918       1     160    65.0    130     80            3     3
# 18062  64.863014       1     140    48.0    170    100            2     1
# 20931  64.904110       1     165    63.0    150     90            2     1
# 22229  64.838356       2     170    91.0    130     90            1     1
# 26469  64.843836       1     169    80.0    120     80            1     1
# 26627  64.805479       1     156    66.0    140     90            3     3
# 27209  64.843836       1     170    66.0    110     70            1     1
# 27847  64.819178       1     154    59.0    130     90            1     1
# 28545  64.843836       2     166    89.0    160    100            1     1
# 33789  64.849315       1     158    65.0    120     80            1     1
# 36603  64.895890       2     163    55.0    120     80            3     1
# 37677  64.887671       2     165    64.0    120     80            1     1
# 40099  64.871233       1     165    74.0    120     80            1     1
# 40672  64.813699       2     168    69.0    120     80            1     1
# 45514  64.841096       1     156    75.0    100     80            1     1
# 46063  64.838356       1     159    58.0    120     60            1     1
# 48563  64.810959       2     165    70.0    120     80            2     1
# 48648  64.810959       2     160    60.0    120     80            1     1
# 50714  64.909589       2     167    68.0    120     80            2     2
# 53176  64.821918       1     166    66.0    120     80            1     1
# 55533  64.854795       1     160    60.0    120     80            1     1
# 55990  64.841096       1     160    70.0    120     90            1     1
# 57191  64.967123       2     175    75.0    120     80            1     1
# 57853  64.863014       1     165    65.0    130     80            1     1
# 59745  64.813699       2     174    70.0    120     80            1     1
# 59784  64.857534       2     170    68.0    110     80            2     2
# 64617  64.857534       2     171    69.0    110     70            1     1
# 67316  64.808219       2     174    80.0    140     90            1     1
# 68005  64.934247       1     178    75.0    120     80            1     1
# 68729  64.849315       1     160    75.0    110     90            1     1
# 69142  64.868493       1     169    70.0    120     80            3     3
#
#        smoke  alco  active  cardio
# 395        0     0       1       0
# 643        0     0       1       0
# 2936       0     0       1       1
# 4295       0     0       1       0
# 9787       0     0       0       0
# 10422      0     0       1       0
# 16439      0     0       0       1
# 18062      0     0       1       1
# 20931      0     0       1       1
# 22229      0     0       1       0
# 26469      0     0       1       0
# 26627      0     0       0       1
# 27209      0     0       0       1
# 27847      0     0       1       0
# 28545      0     0       1       1
# 33789      0     0       1       1
# 36603      1     0       1       1
# 37677      0     0       1       1
# 40099      0     0       1       0
# 40672      0     0       1       0
# 45514      0     0       0       0
# 46063      0     0       1       1
# 48563      1     0       0       1
# 48648      0     0       1       0
# 50714      0     0       0       1
# 53176      0     0       0       0
# 55533      0     0       1       1
# 55990      0     1       1       0
# 57191      0     0       1       1
# 57853      0     0       1       1
# 59745      0     0       1       1
# 59784      0     0       0       1
# 64617      0     0       1       0
# 67316      0     0       1       1
# 68005      0     0       1       1
# 68729      0     0       1       1
# 69142      0     0       1       1

# %% [markdown]
# # TASK #4: VISUALIZE DATASET

# %% [markdown]
# MINI CHALLENGE
# - plot the histogram for all features (use 20 bins)
# - plot the correlation matrix and indicate if there exists any correlations between features

# %%
cardio_df.hist(bins = 20, figsize = (10,10), color = 'r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc047158710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc0475cbd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc0440a9450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc03f219f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc03fa72750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc03faa4f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc03fa5f790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc03fa13f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc03f9d57d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc03f988fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc03f94a7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc03f8fffd0>]],
#       dtype=object)

# %%
sns.pairplot(cardio_df)

# %%
corr_matrix = cardio_df.corr()

# %%
plt.figure(figsize = (16,16))
sns.heatmap(corr_matrix, annot = True)
plt.show()

# %% [markdown]
# # TASK #5: CREATE TRAINING AND TESTING DATASET

# %%
# split the dataframe into target and features

df_target = cardio_df['cardio']
df_final = cardio_df.drop(columns =['cardio'])

# %%
cardio_df.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df_final.shape
# Out:
# (70000, 11)

# %%
df_target.shape
# Out:
# (70000,)

# %%
#spliting the data in to test and train sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_final, df_target, test_size = 0.2)

# %%
X_train.shape
# Out:
# (56000, 11)

# %%
y_train.shape
# Out:
# (56000,)

# %%
X_test.shape
# Out:
# (14000, 11)

# %%
X_test.shape
# Out:
# (14000, 11)

# %% [markdown]
# # TASK #6: TRAIN AND TEST XGBOOST MODEL IN LOCAL MODE (NOTE THAT SAGEMAKER BUILT-IN ALGORITHMS ARE NOT USED HERE)

# %%
# install xgboost

# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.2.1-py3-none-manylinux2010_x86_64.whl (148.9 MB)
#      |████████████████████████████████| 148.9 MB 68 kB/s s eta 0:00:01     |███████████████████████████     | 125.2 MB 72.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.18.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.4.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.2.1

# %%
# use xgboost model in local mode

# note that we have not performed any normalization or scaling since XGBoost is not sensitive to this.
# XGboost is a type of ensemble algorithms and works by selecting thresholds or cut points on features to split a node. 
# It doesn't really matter if the features are scaled or not.


from xgboost import XGBClassifier

# model = XGBClassifier(learning_rate=0.01, n_estimators=100, objective='binary:logistic')
model = XGBClassifier()

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# make predictions on test data

predict = model.predict(X_test)

# %%
predict
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
# Assess trained model performance on training dataset
predict_train = model.predict(X_train)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train, predict_train)
plt.figure()
sns.heatmap(cm, annot=True)

# %%
# print metrics for training dataset

from sklearn.metrics import precision_score, recall_score, accuracy_score

print("Precision = {}".format(precision_score(y_train, predict_train)))
print("Recall = {}".format(recall_score(y_train, predict_train)))
print("Accuracy = {}".format(accuracy_score(y_train, predict_train)))
# Out:
# Precision = 0.9337412326518431
# Recall = 0.8937294672189687
# Accuracy = 0.9151428571428571

# %%
# print metrics for testing dataset

print("Precision = {}".format(precision_score(y_test, predict)))
print("Recall = {}".format(recall_score(y_test, predict)))
print("Accuracy = {}".format(accuracy_score(y_test, predict)))
# Out:
# Precision = 0.7311958668895304
# Recall = 0.6898924731182796
# Accuracy = 0.7191428571428572

# %%
# plot the confusion matrix

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predict)
plt.figure()
sns.heatmap(cm, annot=True)

# %% [markdown]
# MINI CHALLENGE
#  - Retrain the XGBoost algorithm with large number of estimators (n_estimators = 500) and more depth (max_depth = 20)
#  - Comment on the accuracy for both the training and testing data

# %%
model = XGBClassifier(learning_rate=0.01, n_estimators=500,max_depth=20)


model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=20,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=500, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# MINI CHALLENGE
# - Attempt to tune the XGBoost classifier using gridsearch, start with the param_grid listed below
# - Check out these great resources: https://towardsdatascience.com/fine-tuning-xgboost-in-python-like-a-boss-b4543ed8b1e

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
        'gamma': [0.5, 1, 5],   # regularization parameter 
        'subsample': [0.6, 0.8, 1.0], # % of rows taken to build each tree
        'colsample_bytree': [0.6, 0.8, 1.0], # number of columns used by each tree
        'max_depth': [3, 4, 5] # depth of each tree
        }

# %%
xgb_model = XGBClassifier(learning_rate=0.01, n_estimators=100,objective='binary:logistic')

grid = GridSearchCV(xgb_model, param_grid, n_jobs=5, verbose=2, refit=True)

#clf.fit(train[features], train["QuoteConversion_Flag"])

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  31 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=5)]: Done 152 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=5)]: Done 355 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=5)]: Done 405 out of 405 | elapsed: 12.9min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=0.01, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_es...
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              iid='deprecated', n_jobs=5,
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [0.5, 1, 5], 'max_depth': [3, 4, 5],
#                          'subsample': [0.6, 0.8, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
model = XGBClassifier(learning_rate=0.02, n_estimators=600, objective='binary:logistic',
                    silent=True, nthread=1)

# %%
y_predict_optim = grid.predict(X_test)

# %%
y_predict_optim
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# print metrics for testing dataset

print("Precision = {}".format(precision_score(y_test, y_predict_optim)))
print("Recall = {}".format(recall_score(y_test, y_predict_optim)))
print("Accuracy = {}".format(accuracy_score(y_test, y_predict_optim)))
# Out:
# Precision = 0.7665743606450562
# Recall = 0.6746953405017921
# Accuracy = 0.7355714285714285

# %% [markdown]
# # TASK #7: PERFORM DIMENSIONALITY REDUCTION USING PCA ( USING SAGEMAKER)

# %%
# Boto3 is the Amazon Web Services (AWS) Software Development Kit (SDK) for Python
# Boto3 allows Python developer to write software that makes use of services like Amazon S3 and Amazon EC2



import sagemaker
import boto3

# Let's create a Sagemaker session
sagemaker_session = sagemaker.Session()

# Let's define the S3 bucket and prefix that we want to use in this session
bucket = 'sagemaker-practical-fotis'  # Use the default bucket name
prefix = 'pca'  # prefix is the subfolder within the bucket.

#Let's get the execution role for the notebook instance. 
# This is the IAM role that you created when you created your notebook instance. You pass the role to the training job.
# Note that AWS Identity and Access Management (IAM) role that Amazon SageMaker can assume to perform tasks on your behalf (for example, reading training results, called model artifacts, from the S3 bucket and writing training results to Amazon S3). 

role = sagemaker.get_execution_role()

# %%
import io # The io module allows for dealing with various types of I/O (text I/O, binary I/O and raw I/O). 
import numpy as np
import sagemaker.amazon.common as smac # sagemaker common libary

# Code below converts the data in numpy array format to RecordIO format
# This is the format required by Sagemaker PCA

buf = io.BytesIO() # create an in-memory byte array (buf is a buffer I will be writing to)
df_matrix = df_final.to_numpy() # convert the dataframe into 2-dimensional array
smac.write_numpy_to_dense_tensor(buf, df_matrix)
buf.seek(0)

# When you write to in-memory byte arrays, it increments 1 every time you write to it
# Let's reset that back to zero

# %%
df_final
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0      50.391781       2     168    62.0    110     80            1     1
# 1      55.419178       1     156    85.0    140     90            3     1
# 2      51.663014       1     165    64.0    130     70            3     1
# 3      48.282192       2     169    82.0    150    100            1     1
# 4      47.873973       1     156    56.0    100     60            1     1
# ...          ...     ...     ...     ...    ...    ...          ...   ...
# 69995  52.712329       2     168    76.0    120     80            1     1
# 69996  61.920548       1     158   126.0    140     90            2     2
# 69997  52.235616       2     183   105.0    180     90            3     1
# 69998  61.454795       1     163    72.0    135     80            1     2
# 69999  56.273973       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# 0          0     0       1
# 1          0     0       1
# 2          0     0       0
# 3          0     0       1
# 4          0     0       0
# ...      ...   ...     ...
# 69995      1     0       1
# 69996      0     0       1
# 69997      0     1       0
# 69998      0     0       0
# 69999      0     0       1
#
# [70000 rows x 11 columns]

# %%
import os

# Code to upload RecordIO data to S3
 
# Key refers to the name of the file 
 
key = 'pca'

#following code uploads the data in record-io format to S3 bucket to be accessed later for training
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)

# Let's print out the training data location in s3
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)


print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://sagemaker-practical-fotis/pca/train/pca

# %%
# create output placeholder in S3 bucket to store the PCA output

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# training artifacts will be uploaded to: s3://sagemaker-practical-fotis/pca/output

# %%
# This code is used to get the training container of sagemaker built-in algorithms
# all we have to do is to specify the name of the algorithm, that we want to use

# Let's obtain a reference to the pca container image
# Note that all  models are named estimators
# You don't have to specify (hardcode) the region, get_image_uri will get the current region name using boto3.Session


from sagemaker.amazon.amazon_estimator import get_image_uri


container = get_image_uri(boto3.Session().region_name, 'pca')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.

# %%
container
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/pca:1'

# %%
# We have pass in the container, the type of instance that we would like to use for training 
# output path and sagemaker session into the Estimator. 
# We can also specify how many instances we would like to use for training


pca = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sagemaker_session)

# We can tune parameters like the number of features that we are passing in, mode of algorithm, mini batch size and number of pca components


pca.set_hyperparameters(feature_dim=11,
                        num_components=6,
                        subtract_mean=False,
                        algorithm_mode='regular',
                        mini_batch_size=100)


# Pass in the training data from S3 to train the pca model


pca.fit({'train': s3_train_data})

# Let's see the progress using cloudwatch logs
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2020-10-28 15:00:00 Starting - Starting the training job...
# 2020-10-28 15:00:04 Starting - Launching requested ML instances......
# 2020-10-28 15:01:20 Starting - Preparing the instances for training.........
# 2020-10-28 15:02:56 Downloading - Downloading input data
# 2020-10-28 15:02:56 Training - Downloading the training image...
# 2020-10-28 15:03:27 Uploading - Uploading generated training model
# 2020-10-28 15:03:27 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [10/28/2020 15:03:18 INFO 140357761308480] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'true', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto'}
# [10/28/2020 15:03:18 INFO 140357761308480] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'algorithm_mode': u'regular', u'feature_dim': u'11', u'mini_batch_size': u'100', u'subtract_mean': u'False', u'num_components': u'6'}
# [10/28/2020 15:03:19 INFO 140357761308480] Final configuration: {u'num_components': u'6', u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'False', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'feature_dim': u'11', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto', u'mini_batch_size': u'100'}
# [10/28/2020 15:03:19 WARNING 140357761308480] Loggers have already been setup.
# [10/28/2020 15:03:19 INFO 140357761308480] Launching parameter server for role scheduler
# [10/28/2020 15:03:19 INFO 140357761308480] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4668b279-021e-4db0-bb67-1687addee237', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4668b279-021e-4db0-bb67-1687addee237', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-10-28-15-00-00-333', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-2-109-200.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/055e13b4-3471-4613-b27b-2ea976e0ef68', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:717174128108:training-job/pca-2020-10-28-15-00-00-333', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [10/28/2020 15:03:19 INFO 140357761308480] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4668b279-021e-4db0-bb67-1687addee237', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4668b279-021e-4db0-bb67-1687addee237', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.2.109.200', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-10-28-15-00-00-333', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-2-109-200.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/055e13b4-3471-4613-b27b-2ea976e0ef68', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:717174128108:training-job/pca-2020-10-28-15-00-00-333', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [10/28/2020 15:03:19 INFO 140357761308480] Launching parameter server for role server
# [10/28/2020 15:03:19 INFO 140357761308480] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4668b279-021e-4db0-bb67-1687addee237', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4668b279-021e-4db0-bb67-1687addee237', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-10-28-15-00-00-333', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-2-109-200.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/055e13b4-3471-4613-b27b-2ea976e0ef68', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:717174128108:training-job/pca-2020-10-28-15-00-00-333', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [10/28/2020 15:03:19 INFO 140357761308480] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4668b279-021e-4db0-bb67-1687addee237', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4668b279-021e-4db0-bb67-1687addee237', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.2.109.200', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-10-28-15-00-00-333', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-2-109-200.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/055e13b4-3471-4613-b27b-2ea976e0ef68', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:717174128108:training-job/pca-2020-10-28-15-00-00-333', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [10/28/2020 15:03:19 INFO 140357761308480] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4668b279-021e-4db0-bb67-1687addee237', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4668b279-021e-4db0-bb67-1687addee237', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.2.109.200', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-10-28-15-00-00-333', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-2-109-200.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/055e13b4-3471-4613-b27b-2ea976e0ef68', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:717174128108:training-job/pca-2020-10-28-15-00-00-333', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 60 is a shell:scheduler.
# Process 69 is a shell:server.
# Process 1 is a worker.
# [10/28/2020 15:03:19 INFO 140357761308480] Using default worker.
# [10/28/2020 15:03:19 INFO 140357761308480] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [10/28/2020 15:03:19 INFO 140357761308480] Loaded iterator creator application/x-labeled-vector-protobuf for content type ('application/x-labeled-vector-protobuf', '1.0')
# [10/28/2020 15:03:19 INFO 140357761308480] Loaded iterator creator protobuf for content type ('protobuf', '1.0')
# [10/28/2020 15:03:19 INFO 140357761308480] Checkpoint loading and saving are disabled.
# [10/28/2020 15:03:19 INFO 140357761308480] Create Store: dist_sync
# [10/28/2020 15:03:19 INFO 140357761308480] nvidia-smi took: 0.0252249240875 secs to identify 0 gpus
# [10/28/2020 15:03:19 INFO 140357761308480] Number of GPUs being used: 0
# [10/28/2020 15:03:19 INFO 140357761308480] The default executor is <PCAExecutor on cpu(0)>.
# [10/28/2020 15:03:19 INFO 140357761308480] 11 feature(s) found in 'data'.
# [10/28/2020 15:03:19 INFO 140357761308480] <PCAExecutor on cpu(0)> is assigned to batch slice from 0 to 99.
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 759.3660354614258, "sum": 759.3660354614258, "min": 759.3660354614258}}, "EndTime": 1603897399.918897, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1603897399.155149}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1603897399.919119, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1603897399.919071}
#
# [2020-10-28 15:03:19.919] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 762, "num_examples": 1, "num_bytes": 11200}
# [2020-10-28 15:03:20.233] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 306, "num_examples": 700, "num_bytes": 7840000}
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "update.time": {"count": 1, "max": 314.2869472503662, "sum": 314.2869472503662, "min": 314.2869472503662}}, "EndTime": 1603897400.233846, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1603897399.918996}
#
# [10/28/2020 15:03:20 INFO 140357761308480] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 700, "sum": 700.0, "min": 700}, "Number of Batches Since Last Reset": {"count": 1, "max": 700, "sum": 700.0, "min": 700}, "Number of Records Since Last Reset": {"count": 1, "max": 70000, "sum": 70000.0, "min": 70000}, "Total Batches Seen": {"count": 1, "max": 700, "sum": 700.0, "min": 700}, "Total Records Seen": {"count": 1, "max": 70000, "sum": 70000.0, "min": 70000}, "Max Records Seen Between Resets": {"count": 1, "max": 70000, "sum": 70000.0, "min": 70000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1603897400.234166, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "PCA", "epoch": 0}, "StartTime": 1603897399.919521}
#
# [10/28/2020 15:03:20 INFO 140357761308480] #throughput_metric: host=algo-1, train throughput=222395.896299 records/second
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 40.02499580383301, "sum": 40.02499580383301, "min": 40.02499580383301}}, "EndTime": 1603897400.27448, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1603897400.233929}
#
# [10/28/2020 15:03:20 INFO 140357761308480] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1278.1240940093994, "sum": 1278.1240940093994, "min": 1278.1240940093994}, "setuptime": {"count": 1, "max": 18.113136291503906, "sum": 18.113136291503906, "min": 18.113136291503906}}, "EndTime": 1603897400.275018, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1603897400.274533}
#
# Training seconds: 43
# Billable seconds: 43

# %% [markdown]
# MINI CHALLENGE:
#  - Retrain the model with the following number of components 5, 4, and 7

# %% [markdown]
# # TASK #8: DEPLOY THE TRAINED PCA MODEL

# %%
# Deploy the model to perform inference 

pca_reduction = pca.deploy(initial_instance_count = 1,
                                          instance_type = 'ml.m4.xlarge')
# Out:
# -----------------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer


# Content type overrides the data that will be passed to the deployed model, since the deployed model expects data in text/csv format.

# Serializer accepts a single argument, the input data, and returns a sequence of bytes in the specified content type

# Deserializer accepts two arguments, the result data and the response content type, and return a sequence of bytes in the specified content type.

# Reference: https://sagemaker.readthedocs.io/en/stable/predictors.html


#pca_reduction.content_type = 'text/csv'
pca_reduction.serializer = csv_serializer
pca_reduction.deserializer = json_deserializer

# %%
# make prediction on the test data

result = pca_reduction.predict(np.array(df_final))
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
# Since the results are in Json format, we access the scores by iterating through the scores in the predictions
predictions = np.array([r['projection'] for r in result['projections']])

# %%
predictions
# Out:
# array([[-2.89103657e-01,  3.99437475e+00, -1.25495701e+01,
#          6.42405853e+01,  3.68210945e+01, -2.17848068e+02],
#        [ 1.09570193e+00, -4.77767706e+00,  1.23644390e+01,
#          4.45821114e+01,  4.56663399e+01, -2.41025101e+02],
#        [ 1.33668399e+00,  1.79976070e+00, -9.73582458e+00,
#          5.34248428e+01,  5.57539673e+01, -2.23016754e+02],
#        ...,
#        [ 9.36102509e-01,  6.50153160e+00,  2.10844498e+01,
#          4.50918350e+01,  7.45691071e+01, -2.82263916e+02],
#        [ 1.15454197e-03, -8.17430115e+00, -2.97180176e+00,
#          5.16770020e+01,  5.14335823e+01, -2.34024872e+02],
#        [ 3.68915290e-01, -1.09633231e+00, -4.88934517e+00,
#          6.41318741e+01,  4.39791260e+01, -2.28002136e+02]])

# %%
predictions.shape
# Out:
# (70000, 6)

# %%
# Delete the end-point

pca_reduction.delete_endpoint()

# %% [markdown]
# # TASK #9: TRAIN AND EVALUATE XGBOOST MODEL ON DATA AFTER DIMENSIONALITY REDUCTION (USING SAGEMAKER)

# %%
predictions.shape
# Out:
# (70000, 6)

# %%
# Convert the array into dataframe in a way that target variable is set as the first column and is followed by feature columns
# This is because sagemaker built-in algorithm expects the data in this format

train_data = pd.DataFrame({'Target':df_target})
train_data
predictions.shape[1]
# Out:
# 6

# %%
for i in range(predictions.shape[1]):
    train_data[i] = predictions[:,i]

# %%
train_data.head()
# Out:
#    Target         0         1          2          3          4           5
# 0       0 -0.289104  3.994375 -12.549570  64.240585  36.821095 -217.848068
# 1       1  1.095702 -4.777677  12.364439  44.582111  45.666340 -241.025101
# 2       1  1.336684  1.799761  -9.735825  53.424843  55.753967 -223.016754
# 3       1 -0.416388  6.149697   5.682127  43.042397  45.009624 -257.243164
# 4       0 -0.149804  2.675003 -13.209843  63.610920  44.346691 -192.799316

# %%
train_data_size = int(0.9 * train_data.shape[0])
train_data_size
# Out:
# 63000

# %%
# shuffle the data in dataframe and then split the dataframe into train, test and validation sets.

import sklearn 

train_data = sklearn.utils.shuffle(train_data)
train, test, valid = train_data[:train_data_size], train_data[train_data_size:train_data_size + 3500], train_data[train_data_size + 3500:]

# %%
train.shape, test.shape,valid.shape
# Out:
# ((63000, 7), (3500, 7), (3500, 7))

# %%
X_test, y_test = test.drop(columns = ['Target']), test['Target']

# %%
# save train_data and validation_data as csv files

train.to_csv('train.csv',header = False, index = False)
valid.to_csv('valid.csv',header = False, index = False)

# %%
prefix = 'XGBoost-Classifier'
key = 'XGBoost-Classifier'

# %%
# read the data from csv file and then upload the data to s3 bucket
with open('train.csv','rb') as f:
    # The following code uploads the data into S3 bucket to be accessed later for training
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(f)

# Let's print out the training data location in s3
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://sagemaker-practical-fotis/XGBoost-Classifier/train/XGBoost-Classifier

# %%
# reading the data from csv file and then upload the data to s3 bucket
with open('valid.csv','rb') as f:
    # The following code uploads the data into S3 bucket to be accessed later for training
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'valid', key)).upload_fileobj(f)

# Let's print out the validation data location in s3
s3_valid_data = 's3://{}/{}/valid/{}'.format(bucket, prefix, key)
print('uploaded validation data location: {}'.format(s3_valid_data))
# Out:
# uploaded validation data location: s3://sagemaker-practical-fotis/XGBoost-Classifier/valid/XGBoost-Classifier

# %%
# creates output placeholder in S3 bucket to store the linear learner output

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# training artifacts will be uploaded to: s3://sagemaker-practical-fotis/XGBoost-Classifier/output

# %%
# This code is used to get the training container of sagemaker built-in algorithms
# all we have to do is to specify the name of the algorithm, that we want to use

# Let's obtain a reference to the XGBoost container image
# Note that all  models are named estimators
# You don't have to specify (hardcode) the region, get_image_uri will get the current region name using boto3.Session


container = get_image_uri(boto3.Session().region_name, 'xgboost','1.2-1')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
# We have pass in the container, the type of instance that we would like to use for training 
# output path and sagemaker session into the Estimator. 
# We can also specify how many instances we would like to use for training


Xgboost_classifier = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.m4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sagemaker_session)

# To improve the performance of the model, a hyperparameters tuning job need to be run 

Xgboost_classifier.set_hyperparameters(max_depth=30,
                           objective='multi:softmax',
                           num_class= 2,
                           eta = 0.5,
                           num_round = 150
                           )
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
# Create "train", "validation" channels to feed in the model
# Source: https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html


train_input = sagemaker.session.s3_input(s3_data = s3_train_data, content_type='csv',s3_data_type = 'S3Prefix')
valid_input = sagemaker.session.s3_input(s3_data = s3_valid_data, content_type='csv',s3_data_type = 'S3Prefix')

Xgboost_classifier.fit({'train': train_input, 'validation': valid_input})
# Out:
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2020-10-28 16:05:03 Starting - Starting the training job...
# 2020-10-28 16:05:06 Starting - Launching requested ML instances......
# 2020-10-28 16:06:20 Starting - Preparing the instances for training......
# 2020-10-28 16:07:28 Downloading - Downloading input data...
# 2020-10-28 16:07:53 Training - Downloading the training image...
# 2020-10-28 16:08:25 Training - Training image download completed. Training in progress..INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value multi:softmax to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# INFO:root:Train matrix has 63000 rows
# INFO:root:Validation matrix has 3500 rows
# [0]#011train-merror:0.08976#011validation-merror:0.34029
# [1]#011train-merror:0.04835#011validation-merror:0.32800
# [2]#011train-merror:0.02773#011validation-merror:0.33257
# [3]#011train-merror:0.02032#011validation-merror:0.31971
# [4]#011train-merror:0.01538#011validation-merror:0.31571
# [5]#011train-merror:0.00856#011validation-merror:0.31086
# [6]#011train-merror:0.00613#011validation-merror:0.31229
# [7]#011train-merror:0.00508#011validation-merror:0.31029
# [8]#011train-merror:0.00376#011validation-merror:0.30914
# [9]#011train-merror:0.00310#011validation-merror:0.30914
# [10]#011train-merror:0.00287#011validation-merror:0.30886
# [11]#011train-merror:0.00200#011validation-merror:0.31000
# [12]#011train-merror:0.00197#011validation-merror:0.30914
# [13]#011train-merror:0.00191#011validation-merror:0.30800
# [14]#011train-merror:0.00170#011validation-merror:0.30829
# [15]#011train-merror:0.00168#011validation-merror:0.30686
# [16]#011train-merror:0.00168#011validation-merror:0.30629
# [17]#011train-merror:0.00167#011validation-merror:0.30600
# [18]#011train-merror:0.00151#011validation-merror:0.30514
# [19]#011train-merror:0.00127#011validation-merror:0.30514
# [20]#011train-merror:0.00129#011validation-merror:0.30629
# [21]#011train-merror:0.00129#011validation-merror:0.30457
# [22]#011train-merror:0.00081#011validation-merror:0.30429
# [23]#011train-merror:0.00076#011validation-merror:0.30457
# [24]#011train-merror:0.00076#011validation-merror:0.30629
# [25]#011train-merror:0.00075#011validation-merror:0.30743
# [26]#011train-merror:0.00075#011validation-merror:0.30686
# [27]#011train-merror:0.00073#011validation-merror:0.31029
# [28]#011train-merror:0.00073#011validation-merror:0.30914
# [29]#011train-merror:0.00075#011validation-merror:0.30857
# [30]#011train-merror:0.00073#011validation-merror:0.30886
# [31]#011train-merror:0.00073#011validation-merror:0.31000
# [32]#011train-merror:0.00067#011validation-merror:0.30829
# [33]#011train-merror:0.00060#011validation-merror:0.30800
# [34]#011train-merror:0.00054#011validation-merror:0.30886
# [35]#011train-merror:0.00054#011validation-merror:0.30800
# [36]#011train-merror:0.00041#011validation-merror:0.30771
# [37]#011train-merror:0.00032#011validation-merror:0.30686
# [38]#011train-merror:0.00025#011validation-merror:0.30686
# [39]#011train-merror:0.00025#011validation-merror:0.30486
# [40]#011train-merror:0.00022#011validation-merror:0.30400
# [41]#011train-merror:0.00019#011validation-merror:0.30514
# [42]#011train-merror:0.00019#011validation-merror:0.30657
# [43]#011train-merror:0.00019#011validation-merror:0.30629
# [44]#011train-merror:0.00019#011validation-merror:0.30686
# [45]#011train-merror:0.00019#011validation-merror:0.30743
# [46]#011train-merror:0.00019#011validation-merror:0.30714
# [47]#011train-merror:0.00019#011validation-merror:0.30800
# [48]#011train-merror:0.00019#011validation-merror:0.30829
# [49]#011train-merror:0.00019#011validation-merror:0.30886
# [50]#011train-merror:0.00019#011validation-merror:0.30657
# [51]#011train-merror:0.00019#011validation-merror:0.30657
# [52]#011train-merror:0.00019#011validation-merror:0.30686
# [53]#011train-merror:0.00019#011validation-merror:0.30686
# [54]#011train-merror:0.00019#011validation-merror:0.30771
# [55]#011train-merror:0.00019#011validation-merror:0.30800
# [56]#011train-merror:0.00019#011validation-merror:0.30771
# [57]#011train-merror:0.00019#011validation-merror:0.30857
# [58]#011train-merror:0.00019#011validation-merror:0.30771
# [59]#011train-merror:0.00019#011validation-merror:0.30771
# [60]#011train-merror:0.00019#011validation-merror:0.30829
# [61]#011train-merror:0.00019#011validation-merror:0.30743
# [62]#011train-merror:0.00019#011validation-merror:0.30743
# [63]#011train-merror:0.00019#011validation-merror:0.30629
# [64]#011train-merror:0.00019#011validation-merror:0.30743
# [65]#011train-merror:0.00019#011validation-merror:0.30571
# [66]#011train-merror:0.00019#011validation-merror:0.30771
# [67]#011train-merror:0.00019#011validation-merror:0.30857
# [68]#011train-merror:0.00019#011validation-merror:0.30800
# [69]#011train-merror:0.00019#011validation-merror:0.30857
# [70]#011train-merror:0.00019#011validation-merror:0.30857
# [71]#011train-merror:0.00019#011validation-merror:0.30857
# [72]#011train-merror:0.00019#011validation-merror:0.30829
# [73]#011train-merror:0.00019#011validation-merror:0.30771
# [74]#011train-merror:0.00019#011validation-merror:0.30686
# [75]#011train-merror:0.00019#011validation-merror:0.30486
# [76]#011train-merror:0.00019#011validation-merror:0.30543
# [77]#011train-merror:0.00019#011validation-merror:0.30429
# [78]#011train-merror:0.00019#011validation-merror:0.30229
# [79]#011train-merror:0.00019#011validation-merror:0.30343
# [80]#011train-merror:0.00019#011validation-merror:0.30286
# [81]#011train-merror:0.00019#011validation-merror:0.30429
# [82]#011train-merror:0.00019#011validation-merror:0.30429
# [83]#011train-merror:0.00019#011validation-merror:0.30429
# [84]#011train-merror:0.00019#011validation-merror:0.30343
# [85]#011train-merror:0.00019#011validation-merror:0.30429
# [86]#011train-merror:0.00019#011validation-merror:0.30257
# [87]#011train-merror:0.00019#011validation-merror:0.30286
# [88]#011train-merror:0.00019#011validation-merror:0.30343
# [89]#011train-merror:0.00019#011validation-merror:0.30400
# [90]#011train-merror:0.00019#011validation-merror:0.30486
# [91]#011train-merror:0.00019#011validation-merror:0.30429
# [92]#011train-merror:0.00019#011validation-merror:0.30571
# [93]#011train-merror:0.00019#011validation-merror:0.30486
# [94]#011train-merror:0.00019#011validation-merror:0.30457
# [95]#011train-merror:0.00019#011validation-merror:0.30371
# [96]#011train-merror:0.00019#011validation-merror:0.30486
# [97]#011train-merror:0.00019#011validation-merror:0.30514
# [98]#011train-merror:0.00019#011validation-merror:0.30429
# [99]#011train-merror:0.00019#011validation-merror:0.30429
# [100]#011train-merror:0.00019#011validation-merror:0.30457
# [101]#011train-merror:0.00019#011validation-merror:0.30486
# [102]#011train-merror:0.00019#011validation-merror:0.30571
# [103]#011train-merror:0.00019#011validation-merror:0.30657
# [104]#011train-merror:0.00019#011validation-merror:0.30629
# [105]#011train-merror:0.00019#011validation-merror:0.30686
# [106]#011train-merror:0.00019#011validation-merror:0.30714
# [107]#011train-merror:0.00019#011validation-merror:0.30686
# [108]#011train-merror:0.00019#011validation-merror:0.30686
# [109]#011train-merror:0.00019#011validation-merror:0.30657
# [110]#011train-merror:0.00019#011validation-merror:0.30800
# [111]#011train-merror:0.00019#011validation-merror:0.30771
# [112]#011train-merror:0.00019#011validation-merror:0.30771
# [113]#011train-merror:0.00019#011validation-merror:0.30743
# [114]#011train-merror:0.00019#011validation-merror:0.30686
# [115]#011train-merror:0.00019#011validation-merror:0.30714
# [116]#011train-merror:0.00019#011validation-merror:0.30657
# [117]#011train-merror:0.00019#011validation-merror:0.30657
# [118]#011train-merror:0.00019#011validation-merror:0.30657
# [119]#011train-merror:0.00019#011validation-merror:0.30686
# [120]#011train-merror:0.00019#011validation-merror:0.30686
# [121]#011train-merror:0.00019#011validation-merror:0.30657
# [122]#011train-merror:0.00019#011validation-merror:0.30714
# [123]#011train-merror:0.00019#011validation-merror:0.30743
# [124]#011train-merror:0.00019#011validation-merror:0.30829
# [125]#011train-merror:0.00019#011validation-merror:0.30743
# [126]#011train-merror:0.00019#011validation-merror:0.30743
# [127]#011train-merror:0.00019#011validation-merror:0.30743
# [128]#011train-merror:0.00019#011validation-merror:0.30829
# [129]#011train-merror:0.00019#011validation-merror:0.30800
# [130]#011train-merror:0.00019#011validation-merror:0.30743
# [131]#011train-merror:0.00019#011validation-merror:0.30771
# [132]#011train-merror:0.00019#011validation-merror:0.30829
# [133]#011train-merror:0.00019#011validation-merror:0.30914
# [134]#011train-merror:0.00019#011validation-merror:0.31000
# [135]#011train-merror:0.00019#011validation-merror:0.31057
# [136]#011train-merror:0.00019#011validation-merror:0.31000
# [137]#011train-merror:0.00019#011validation-merror:0.30857
# [138]#011train-merror:0.00019#011validation-merror:0.30886
# [139]#011train-merror:0.00019#011validation-merror:0.30914
# [140]#011train-merror:0.00019#011validation-merror:0.30971
# [141]#011train-merror:0.00019#011validation-merror:0.31057
# [142]#011train-merror:0.00019#011validation-merror:0.30971
# [143]#011train-merror:0.00019#011validation-merror:0.30829
# [144]#011train-merror:0.00019#011validation-merror:0.30914
# [145]#011train-merror:0.00019#011validation-merror:0.30829
# [146]#011train-merror:0.00019#011validation-merror:0.30857
# [147]#011train-merror:0.00019#011validation-merror:0.30800
# [148]#011train-merror:0.00019#011validation-merror:0.30857
# [149]#011train-merror:0.00019#011validation-merror:0.30771
#
# 2020-10-28 16:09:45 Uploading - Uploading generated training model
# 2020-10-28 16:09:45 Completed - Training job completed
# Training seconds: 137
# Billable seconds: 137

# %% [markdown]
# MINI CHALLENGE
# - Retrain the XGBoost model with deeper trees (max_depth)

# %%
Xgboost_classifier

# %% [markdown]
# # TASK #10: DEPLOY AND TEST THE TRAINED XGBOOST MODEL

# %%
Xgboost_classifierD = Xgboost_classifier.deploy(initial_instance_count = 1,
                                          instance_type = 'ml.m4.xlarge')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b3f1bb774bf6> in <module>
# ----> 1 Xgboost_classifierD = Xgboost_classifier.deploy(initial_instance_count = 1,
#       2                                           instance_type = 'ml.m4.xlarge')
#
# NameError: name 'Xgboost_classifier' is not defined

# %%
# Content type over-rides the data that will be passed to the deployed model, since the deployed model expects data in text/csv format, we specify this as content -type.
# Serializer accepts a single argument, the input data, and returns a sequence of bytes in the specified content type
#Reference: https://sagemaker.readthedocs.io/en/stable/predictors.html

from sagemaker.predictor import csv_serializer, json_deserializer

#Xgboost_classifierD.content_type = 'text/csv'
Xgboost_classifierD.serializer = csv_serializer
Xgboost_classifierD.deserializer = None
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3fcefead23b5> in <module>
#       3 #Reference: https://sagemaker.readthedocs.io/en/stable/predictors.html
#       4
# ----> 5 from sagemaker.predictor import csv_serializer, json_deserializer
#       6
#       7 #Xgboost_classifierD.content_type = 'text/csv'
#
# ModuleNotFoundError: No module named 'sagemaker'

# %%
# make prediction

XGB_prediction = Xgboost_classifierD.predict(np.array(X_test))
# Out:
# <module 'numpy' from '/opt/conda/lib/python3.7/site-packages/numpy/__init__.py'>

# %%
# custom code to convert the values in bytes format to array

def bytes_2_array(x):
    
    #makes entire prediction as string and splits based on ','
    l = str(x).split(',')
    
    #Since the first element contains unwanted characters like (b,',') we remove them
    l[0] = l[0][2:]
    #same-thing as above remove the unwanted last character (')
    l[-1] = l[-1][:-1]
    
    #iterating through the list of strings and converting them into float type
    for i in range(len(l)):
        l[i] = float(l[i])
        
    #converting the list to into array
    l = np.array(l).astype('float32')
    
    #reshape one-dimensional array to two-dimentaional array
    return l.reshape(-1,1)

# %%
predicted_values = bytes_2_array(XGB_prediction)

# %%
predicted_values

# %%
y_test = np.array(y_test)
y_test = y_test.reshape(-1,1)

# %%
y_test

# %%
# plot metrics

from sklearn.metrics import precision_score, recall_score, accuracy_score

print("Precision = {}".format(precision_score(y_test, predicted_values, average='macro')))
print("Recall = {}".format(recall_score(y_test, predicted_values, average='macro')))
print("Accuracy = {}".format(accuracy_score(y_test, predicted_values)))

# %%
# plot confusion matrix

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predicted_values)
plt.figure()
sns.heatmap(cm, annot=True)

# %%
# Delete the end-point

Xgboost_classifier.delete_endpoint()
# Out:
# The function delete_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
